# %% [markdown]
# """
# 테스트 코드
# """

# %%
import xlrd
import csv

def excel_to_csv(excel_file_path, csv_file_path):
    wb = xlrd.open_workbook(excel_file_path)
    sh = wb.sheet_by_name('Characteristics')
    your_csv_file = open(csv_file_path, 'wb')
    wr = csv.writer(your_csv_file, quoting=csv.QUOTE_ALL)

    for rownum in xrange(sh.nrows):
        wr.writerow(sh.row_values(rownum))

    your_csv_file.close()

# %%
excel_file_path = './data/dividend_achievers.xlsx'
csv_file_path = './data/dividend_achievers.csv'
excel_to_csv(excel_file_path, csv_file_path)
# Out:
# ---------------------------------------------------------------------------
# XLRDError                                 Traceback (most recent call last)
# Input In [8], in <cell line: 3>()
#       1 excel_file_path = './data/dividend_achievers.xlsx'
#       2 csv_file_path = './data/dividend_achievers.csv'
# ----> 3 excel_to_csv(excel_file_path, csv_file_path)
#
# Input In [7], in excel_to_csv(excel_file_path, csv_file_path)
#       4 def excel_to_csv(excel_file_path, csv_file_path):
# ----> 5     wb = xlrd.open_workbook(excel_file_path)
#       6     sh = wb.sheet_by_name('Characteristics')
#       7     your_csv_file = open(csv_file_path, 'wb')
#
# File ~\anaconda3\lib\site-packages\xlrd\__init__.py:170, in open_workbook(filename, logfile, verbosity, use_mmap, file_contents, encoding_override, formatting_info, on_demand, ragged_rows, ignore_workbook_corruption)
#     167 # We have to let unknown file formats pass through here, as some ancient
#     168 # files that xlrd can parse don't start with the expected signature.
#     169 if file_format and file_format != 'xls':
# --> 170     raise XLRDError(FILE_FORMAT_DESCRIPTIONS[file_format]+'; not supported')
#     172 bk = open_workbook_xls(
#     173     filename=filename,
#     174     logfile=logfile,
#    (...)
#     182     ignore_workbook_corruption=ignore_workbook_corruption,
#     183 )
#     185 return bk
#
# XLRDError: Excel xlsx file; not supported

# %%
import StockScore

# %%
import yfinance as yf
import requests
import pandas as pd
import ftplib
import io
import re
import json
import datetime

msft = yf.Ticker("msft")

#company_name = msft.info['longName']
msft.info
# Out:
# {'regularMarketPrice': None,
#  'preMarketPrice': None,
#  'logo_url': '',
#  'trailingPegRatio': 2.1027}

# %%
recommendations = msft.recommendations

# %%
print(recommendations)
# Out:
# None

# %%
Amazon = yf.Ticker("AMZN")
print(Amazon.info)
# Out:
# {'regularMarketPrice': None, 'preMarketPrice': None, 'logo_url': '', 'trailingPegRatio': 5.0392}

# %%
from yahoo_fin import stock_info
ticker = 'msft'
stock_stats = stock_info.get_stats(ticker)

# %%
def _parse_json(url, headers = {'User-agent': 'Mozilla/5.0'}):
    html = requests.get(url=url, headers = headers).text

    json_str = html.split('root.App.main =')[1].split(
        '(this)')[0].split(';\n}')[0].strip()
    
    try:
        data = json.loads(json_str)[
            'context']['dispatcher']['stores']['QuoteSummaryStore']
    except:
        return '{}'
    else:
        # return data
        new_data = json.dumps(data).replace('{}', 'null')
        new_data = re.sub(r'\{[\'|\"]raw[\'|\"]:(.*?),(.*?)\}', r'\1', new_data)

        json_info = json.loads(new_data)

        return

# %%
# Company Information Functions
def get_company_info(ticker):
    '''Scrape the company information for a ticker
       @param: ticker
    '''
    site = f"https://finance.yahoo.com/quote/{ticker}/profile?p={ticker}"
    json_info = _parse_json(site)
    print(json_info)
    #json_info = json_info["assetProfile"]
    #info_frame = pd.DataFrame.from_dict(json_info,
    #                                    orient="index",
    #                                    columns=["Value"])
    #info_frame = info_frame.drop("companyOfficers", axis="index")
    #info_frame.index.name = "Breakdown"

# %%
company_info = get_company_info(ticker)
company_info
# Out:
# {}

# %%
stock_stats
# Out:
#                                          Attribute         Value
# 0                                Beta (5Y Monthly)          0.93
# 1                                 52-Week Change 3       -23.11%
# 2                          S&P500 52-Week Change 3       -14.58%
# 3                                   52 Week High 3        315.95
# 4                                    52 Week Low 3        213.43
# 5                          50-Day Moving Average 3        239.75
# 6                         200-Day Moving Average 3        258.14
# 7                              Avg Vol (3 month) 3        30.34M
# 8                               Avg Vol (10 day) 3        31.16M
# 9                             Shares Outstanding 5         7.45B
# 10                    Implied Shares Outstanding 6           NaN
# 11                                         Float 8         7.45B
# 12                            % Held by Insiders 1         0.06%
# 13                        % Held by Institutions 1        73.35%
# 14                   Shares Short (Dec 29, 2022) 4        38.19M
# 15                    Short Ratio (Dec 29, 2022) 4          1.32
# 16               Short % of Float (Dec 29, 2022) 4         0.51%
# 17  Short % of Shares Outstanding (Dec 29, 2022) 4         0.51%
# 18       Shares Short (prior month Nov 29, 2022) 4        40.45M
# 19                  Forward Annual Dividend Rate 4          2.72
# 20                 Forward Annual Dividend Yield 4         1.14%
# 21                 Trailing Annual Dividend Rate 3          2.54
# 22                Trailing Annual Dividend Yield 3         1.06%
# 23                 5 Year Average Dividend Yield 4          1.15
# 24                                  Payout Ratio 4        26.70%
# 25                                 Dividend Date 3  Mar 08, 2023
# 26                              Ex-Dividend Date 4  Feb 14, 2023
# 27                             Last Split Factor 2           2:1
# 28                               Last Split Date 3  Feb 17, 2003
# 29                                Fiscal Year Ends  Jun 29, 2022
# 30                       Most Recent Quarter (mrq)  Sep 29, 2022
# 31                                   Profit Margin        34.37%
# 32                          Operating Margin (ttm)        41.69%
# 33                          Return on Assets (ttm)        15.22%
# 34                          Return on Equity (ttm)        42.88%
# 35                                   Revenue (ttm)       203.07B
# 36                         Revenue Per Share (ttm)         27.14
# 37                  Quarterly Revenue Growth (yoy)        10.60%
# 38                              Gross Profit (ttm)       135.62B
# 39                                          EBITDA        98.84B
# 40                  Net Income Avi to Common (ttm)        69.79B
# 41                               Diluted EPS (ttm)          9.29
# 42                 Quarterly Earnings Growth (yoy)       -14.40%
# 43                                Total Cash (mrq)       107.24B
# 44                      Total Cash Per Share (mrq)         14.39
# 45                                Total Debt (mrq)        77.14B
# 46                         Total Debt/Equity (mrq)         44.44
# 47                             Current Ratio (mrq)          1.84
# 48                      Book Value Per Share (mrq)         23.28
# 49                       Operating Cash Flow (ttm)        87.69B
# 50                    Levered Free Cash Flow (ttm)        46.16B

# %%
from fuzzywuzzy import process
import requests

def getCompany(text):
    r = requests.get('https://api.iextrading.com/1.0/ref-data/symbols')
    stockList = r.json()
    return process.extractOne(text, stockList)[0]


getCompany('GOOG')
getCompany('Alphabet')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [26], in <cell line: 1>()
# ----> 1 from fuzzywuzzy import process
#       2 import requests
#       4 def getCompany(text):
#
# ModuleNotFoundError: No module named 'fuzzywuzzy'
